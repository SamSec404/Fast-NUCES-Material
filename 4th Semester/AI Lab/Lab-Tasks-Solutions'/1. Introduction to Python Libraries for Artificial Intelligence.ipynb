# %%
import numpy as np

# %%
ArrayOfEvenNumbers = np.arange(200,241,2)

# %%
print(ArrayOfEvenNumbers)
# Out:
# [200 202 204 206 208 210 212 214 216 218 220 222 224 226 228 230 232 234
#  236 238 240]

# %%
ArrayOfRandomNumbers = np.random.rand(10)

# %%
print(ArrayOfRandomNumbers)
# Out:
# [0.76385485 0.91653658 0.40653545 0.64835443 0.53447488 0.65004926
#  0.47583451 0.66100647 0.16424561 0.28280622]

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=np.array([0,2,4,6,8,10])

# %%
y1= 2*x + 1

# %%
y2=np.cos(x)

# %%
plt.figure(figsize=(10,6))

# %%
plt.plot(x, y1, marker='o', label='y = 2x +1')
plt.plot(x, y2, marker='x', label='cos')

plt.title('Straight line and cosine')
plt.xlabel('X', fontsize=15)
plt.ylabel('Y', fontsize=15)

plt.legend()

# %%
import numpy as np

# %%
import pandas as pd

# %%
OriginalSeries=pd.Series([100,200,'Python',300.12,400])

# %%
OriginalSeries
# Out:
# 0       100
# 1       200
# 2    Python
# 3    300.12
# 4       400
# dtype: object

# %%
ConvertedSeries=pd.to_numeric(OriginalSeries,errors='coerce')

# %%
ConvertedSeries
# Out:
# 0    100.00
# 1    200.00
# 2       NaN
# 3    300.12
# 4    400.00
# dtype: float64

# %%
import pandas as pd

# %%
Data={'Col1': [0,1,2,3,4],
      'Col2': [3,4,5,6,7],
      'Col3': [5,6,7,8,9]}

# %%
df=pd.DataFrame(Data)

# %%
df
# Out:
#    Col1  Col2  Col3
# 0     0     3     5
# 1     1     4     6
# 2     2     5     7
# 3     3     6     8
# 4     4     7     9

# %%
NewDataFrame=df[df['Col1']!=4]

# %%
NewDataFrame
# Out:
#    Col1  Col2  Col3
# 0     0     3     5
# 1     1     4     6
# 2     2     5     7
# 3     3     6     8
